# %% [markdown]
# # Introduction to Pandas Lab
#
# Complete the following set of exercises to solidify your knowledge of Pandas fundamentals.

# %% [markdown]
# ### 1. Import Numpy and Pandas and alias them to `np` and `pd` respectively.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Create a Pandas Series containing the elements of the list below.

# %%
lst = [5.7, 75.2, 74.4, 84.0, 66.5, 66.3, 55.8, 75.7, 29.1, 43.7]

# %%
serie = pd.Series(lst)

# %% [markdown]
# ### 3. Use indexing to return the third value in the Series above.
#
# *Hint: Remember that indexing begins at 0.*

# %%
print(f' The third value in the Panda serie in {serie[3]}.')
# Out:
#  The third value in the Panda serie in 84.0.

# %% [markdown]
# ### 4. Create a Pandas DataFrame from the list of lists below. Each sublist should be represented as a row.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
data = pd.DataFrame(b)
data
# Out:
#       0     1     2     3     4
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# ### 5. Rename the data frame columns based on the names in the list below.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
colnames = ['Score_1', 'Score_2', 'Score_3', 'Score_4', 'Score_5']

# %%
data.columns = ['Score_1', 'Score_2', 'Score_3', 'Score_4', 'Score_5']

data
# Out:
#    Score_1  Score_2  Score_3  Score_4  Score_5
# 0     53.1     95.0     67.5     35.0     78.4
# 1     61.3     40.8     30.8     37.8     87.6
# 2     20.6     73.2     44.2     14.6     91.8
# 3     57.4      0.1     96.1      4.2     69.5
# 4     83.6     20.5     85.4     22.8     35.9
# 5     49.0     69.0      0.1     31.8     89.1
# 6     23.3     40.7     95.0     83.8     26.9
# 7     27.6     26.4     53.8     88.8     68.5
# 8     96.6     96.4     53.4     72.4     50.1
# 9     73.7     39.0     43.2     81.6     34.7

# %% [markdown]
# ### 6. Create a subset of this data frame that contains only the Score 1, 3, and 5 columns.

# %%
sub_set = data[1:6]

# %% [markdown]
# ### 7. From the original data frame, calculate the average Score_3 value.

# %%
print(f'The average values from the Score_3 column is {data.Score_3.mean()}')


### Limitar decimales
# Out:
# The average values from the Score_3 column is 56.95000000000001

# %% [markdown]
# ### 8. From the original data frame, calculate the maximum Score_4 value.

# %%
print(f'The maximum score from the Score_4 column is {data.Score_3.max()}')
# Out:
# The maximum score from the Score_4 is 96.1

# %% [markdown]
# ### 9. From the original data frame, calculate the median Score 2 value.

# %%
print(f'The median score from Score2 columns is {data.Score_2.median()}')
# Out:
# The median score from Score2 columns is 40.75

# %% [markdown]
# ### 10. Create a Pandas DataFrame from the dictionary of product orders below.

# %%
orders = {'Description': ['LUNCH BAG APPLE DESIGN',
  'SET OF 60 VINTAGE LEAF CAKE CASES ',
  'RIBBON REEL STRIPES DESIGN ',
  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
  'PLAYING CARDS JUBILEE UNION JACK',
  'POPCORN HOLDER',
  'BOX OF VINTAGE ALPHABET BLOCKS',
  'PARTY BUNTING',
  'JAZZ HEARTS ADDRESS BOOK',
  'SET OF 4 SANTA PLACE SETTINGS'],
 'Quantity': [1, 24, 1, 2880, 2, 7, 1, 4, 10, 48],
 'UnitPrice': [1.65, 0.55, 1.65, 0.18, 1.25, 0.85, 11.95, 4.95, 0.19, 1.25],
 'Revenue': [1.65, 13.2, 1.65, 518.4, 2.5, 5.95, 11.95, 19.8, 1.9, 60.0]}

# %%
data_dic = pd.DataFrame(orders)
data_dic
# Out:
#                           Description  Quantity  UnitPrice  Revenue
# 0              LUNCH BAG APPLE DESIGN         1       1.65     1.65
# 1  SET OF 60 VINTAGE LEAF CAKE CASES         24       0.55    13.20
# 2         RIBBON REEL STRIPES DESIGN          1       1.65     1.65
# 3   WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880       0.18   518.40
# 4    PLAYING CARDS JUBILEE UNION JACK         2       1.25     2.50
# 5                      POPCORN HOLDER         7       0.85     5.95
# 6      BOX OF VINTAGE ALPHABET BLOCKS         1      11.95    11.95
# 7                       PARTY BUNTING         4       4.95    19.80
# 8            JAZZ HEARTS ADDRESS BOOK        10       0.19     1.90
# 9       SET OF 4 SANTA PLACE SETTINGS        48       1.25    60.00

# %% [markdown]
# ### 11. Calculate the total quantity ordered and revenue generated from these orders.

# %%
print(f'The total quantity ordered is {data_dic.Quantity.sum()}.\n') 
print(f'The total revenue is {data_dic.Revenue.sum()}')
# Out:
# The total quantity ordered is 2978.
#
# The total revenue is 637.0

# %% [markdown]
# ### 12. Obtain the prices of the most expensive and least expensive items ordered and print the difference.

# %%
print(f' The price of the most expensice itme is {data_dic.UnitPrice.max()}.\n The price for least expensive item is {data_dic.UnitPrice.min()}\n The difference between the max and the min price is {(data_dic.UnitPrice.max())-(data_dic.UnitPrice.min())}.\n')
# Out:
#  The price of the most expensice itme is 11.95.
#  The price for least expensive item is 0.18
#  The difference between the max and the min price is 11.77.

# %%
data_dic.loc[(data_dic['Description']=='D') & (data_dic.UnitPrice.max())]#SELECT SPECIFIC COLUMN AND ROW
data_dic.Description[data_dic.UnitPrice==data_dic.UnitPrice.max()]
filtrado_ = df.loc[(df["year"] > 2014) & (df["region"]=="Albany"), ["type", "year", "region"]] #Select columns you like

# %%
data_dic.iloc[:2,[1,3]]
# Out:
#    Quantity  Revenue
# 0         1     1.65
# 1        24    13.20

# %%
data_dic[data_dic.UnitPrice==data_dic.UnitPrice.max()]
# Out:
#                       Description  Quantity  UnitPrice  Revenue
# 6  BOX OF VINTAGE ALPHABET BLOCKS         1      11.95    11.95

# %% [markdown]
# ## Let's load another dataset for more exercisesº

# %%
# Run this code:
admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# ### 1 - Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
admissions.notna()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating   SOP   LOR  CGPA  \
# 0          True       True         True               True  True  True  True
# 1          True       True         True               True  True  True  True
# 2          True       True         True               True  True  True  True
# 3          True       True         True               True  True  True  True
# 4          True       True         True               True  True  True  True
# ..          ...        ...          ...                ...   ...   ...   ...
# 380        True       True         True               True  True  True  True
# 381        True       True         True               True  True  True  True
# 382        True       True         True               True  True  True  True
# 383        True       True         True               True  True  True  True
# 384        True       True         True               True  True  True  True
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# ###  2 -  Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         385 non-null    int64
#  1   GRE Score          385 non-null    int64
#  2   TOEFL Score        385 non-null    int64
#  3   University Rating  385 non-null    int64
#  4   SOP                385 non-null    float64
#  5   LOR                385 non-null    float64
#  6   CGPA               385 non-null    float64
#  7   Research           385 non-null    int64
#  8   Chance of Admit    385 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 27.2 KB

# %%
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
admissions['index']=admissions['Serial No.']

# %%
admissions = admissions.set_index("index")

# %%
admissions
# Out:
#        Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# index
# 1               1        337          118                  4  4.5  4.5  9.65
# 2               2        316          104                  3  3.0  3.5  8.00
# 3               3        322          110                  3  3.5  2.5  8.67
# 4               4        314          103                  2  2.0  3.0  8.21
# 5               5        330          115                  5  4.5  3.0  9.34
# ...           ...        ...          ...                ...  ...  ...   ...
# 381           381        324          110                  3  3.5  3.5  9.04
# 382           382        325          107                  3  3.0  3.5  9.11
# 383           383        330          116                  4  5.0  4.5  9.45
# 384           384        312          103                  3  3.5  4.0  8.78
# 385           385        333          117                  4  5.0  4.0  9.66
#
#        Research  Chance of Admit
# ...

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
otro = {"GRE Score": "GREScore"}

admissions.rename(columns = otro, inplace=True)

# %%
admissions.GREScore.unique()
# Out:
# array([337, 316, 322, 314, 330, 321, 308, 302, 323, 327, 328, 307, 311,
#        317, 319, 318, 303, 325, 334, 336, 298, 295, 310, 300, 338, 340,
#        331, 320, 299, 304, 313, 332, 326, 329, 339, 312, 324, 309, 315,
#        301, 296, 294, 306, 305, 290, 335, 333, 297, 293])

# %%
admissions.CGPA.unique()
# Out:
# array([9.65, 8.  , 8.67, 8.21, 9.34, 8.2 , 7.9 , 8.6 , 9.  , 9.1 , 8.3 ,
#        8.7 , 8.8 , 8.5 , 8.4 , 9.5 , 9.7 , 9.8 , 7.5 , 7.2 , 7.3 , 8.1 ,
#        9.4 , 9.6 , 9.2 , 7.8 , 7.7 , 9.3 , 8.85, 7.4 , 7.6 , 6.8 , 8.92,
#        9.02, 8.64, 9.22, 9.16, 9.64, 9.76, 9.45, 9.04, 8.9 , 8.56, 8.72,
#        8.22, 7.54, 7.36, 8.02, 9.36, 8.66, 8.42, 8.28, 8.14, 7.92, 7.66,
#        8.03, 7.88, 7.84, 8.96, 9.24, 8.88, 8.46, 8.12, 8.25, 8.47, 9.05,
#        8.78, 9.18, 9.46, 9.38, 8.48, 8.68, 8.34, 8.45, 8.62, 7.46, 7.28,
#        8.84, 9.56, 9.48, 8.36, 9.32, 8.71, 9.35, 8.65, 9.28, 8.77, 8.16,
#        9.08, 9.12, 9.15, 9.44, 9.92, 9.11, 8.26, 9.43, 9.06, 8.75, 8.89,
#        8.69, 7.86, 9.01, 8.97, 8.33, 8.27, 7.98, 8.04, 9.07, 9.13, 9.23,
#        8.87, 8.98, 8.94, 9.53, 8.76, 8.52, 8.54, 9.91, 9.87, 7.65, 7.89,
#        9.14, 9.66, 9.78, 9.42, 9.26, 8.23, 8.07, 9.31, 9.17, 9.19, 8.37,
#        7.68, 8.15, 8.73, 8.83, 8.57, 9.68, 8.09, 8.79, 8.17, 7.64, 8.01,
# ...

# %% [markdown]
# ### 3 - In this part of the lab, we would like to test complex conditions on the entire data set at once. Let's start by finding the number of rows where the CGPA is greater than 9 and the student has performed an investigation.

# %%
admissions.loc[(admissions["CGPA"] > 9) & (admissions["Research"]== 1)]
# Out:
#        Serial No.  GREScore  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# index
# 1               1       337          118                  4  4.5  4.5  9.65
# 5               5       330          115                  5  4.5  3.0  9.34
# 11             11       328          112                  4  4.0  4.5  9.10
# 20             20       328          116                  5  5.0  5.0  9.50
# 21             21       334          119                  5  5.0  4.5  9.70
# ...           ...       ...          ...                ...  ...  ...   ...
# 380           380       329          111                  4  4.5  4.0  9.23
# 381           381       324          110                  3  3.5  3.5  9.04
# 382           382       325          107                  3  3.0  3.5  9.11
# 383           383       330          116                  4  5.0  4.5  9.45
# 385           385       333          117                  4  5.0  4.0  9.66
#
#        Research  Chance of Admit
# index
# ...

# %% [markdown]
# #### 4 - Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
otro = {"Chance of Admit": "Chance_of_Admit"}

admissions.rename(columns = otro, inplace=True)

# %%
admissions.loc[(admissions["CGPA"] > 9) & (admissions["SOP"] < 3.5)]
# Out:
#        Serial No.  GREScore  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# index
# 29             29       338          118                  4  3.0  4.5  9.40
# 63             63       327          114                  3  3.0  3.0  9.02
# 141           141       326          114                  3  3.0  3.0  9.11
# 218           218       324          111                  4  3.0  3.0  9.01
# 382           382       325          107                  3  3.0  3.5  9.11
#
#        Research  Chance_of_Admit
# index
# 29            1             0.91
# 63            0             0.61
# 141           1             0.83
# 218           1             0.82
# 382           1             0.84

# %%
print(f'The mean chance of admission is {admissions.Chance_of_Admit.mean()}')
# Out:
# The mean chance of admission is 0.7239220779220779

# %% [markdown]
# Let's create a new column based on the TOEFL Score column, where we put True if the TOEFL value is greater than 100 and False if it is less. We are going to do it with a function and an apply.
# To do this, we first create a function that receives an argument. The function will return True if the parameter entered is greater than 100, otherwise it will return False.

# %%
otro = {"TOEFL Score": "TOEFL_Score"}

admissions.rename(columns = otro, inplace=True)

# %%
def greater(x):
    if x > 100:
        return True
    else:
        return False

# %%
admissions["TOEFL_TF"] = admissions.TOEFL_Score.apply(greater)

# %% [markdown]
# Now we create a new column called "Decision" and apply to the TOEFL Score column

# %%
admissions.sample()
# Out:
#        Serial No.  GREScore  TOEFL_Score  University Rating  SOP  LOR  CGPA  \
# index
# 192           192       315          110                  2  3.5  3.0  8.46
#
#        Research  Chance_of_Admit  TOEFL_TF
# index
# 192           1             0.72      True

# %%
otro = {"TOEFL_Scoree": "Decision"}

admissions.rename(columns = otro, inplace=True)

# %% [markdown]
# Create a column called `decision2` in the `admissions` dataframe. Assign 1 to this column if the value of `SOP` is greater than 3 and 0 otherwise.
# HINT (use np.where)

# %%
def decis(x):
    if x > 3:
        return 1
    else:
        return 0

# %%
admissions["decision2"] = admissions.SOP.apply(decis)

# %%
admissions.sample()
# Out:
#        Serial No.  GREScore  TOEFL_Score  University Rating  SOP  LOR  CGPA  \
# index
# 357           357       324          110                  3  3.5  3.0  9.22
#
#        Research  Chance_of_Admit  TOEFL_TF  decision2
# index
# 357           1             0.89      True          1
